# %%
import time
import random
import matplotlib.pyplot as plt
import numpy as np
from random import randint

plt.style.use('fivethirtyeight')

# %%
def maximum(values):
    answer = None
    for value in values:
        if answer == None or answer < value:
            answer = value
    return answer

def sum_values(values):
    total = 0            
    for value in values: 
        total += value   
    return total  

def gen_input(length):
    return [random.randint(-1000, 1000) for _ in range(length)]

# add your code below
times = []
for length in range(1, 501):  
    values = gen_input(length)
    start = time.time()   
    maximum(values)        
    end = time.time()       
    runtime = end - start       
    times.append(runtime*1000)

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
ax.plot(times,label="Real execution time")
ax.set_xlabel("Array Size")
ax.set_ylabel("Runtime (ms)")

z = np.polyfit(range(1, 501),times, 1)
p = np.poly1d(z)

ax.plot(range(1, 501),p(range(1, 501)),label="Time complexity model")
ax.legend()
plt.show()

# %%
def dummy(alpha,beta,values):
  new_values = []
  for value in values:
    new_values.append(alpha + beta * value)
  return new_values

# %%
values = range(1, 501)
curve_1 = dummy(0,2, values)
curve_2 = dummy(2,1, values)
curve_3 = dummy(3,6, values)
fig, ax = plt.subplots(1,1,figsize=(10,6))
ax.plot(curve_1,label="2N")
ax.plot(curve_2,label="N + 2")
ax.plot(curve_3,label="6N + 3")
ax.set_xlabel("Array Size (N)")
ax.set_ylabel("Number of Operations")
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

def append_cost(array_length, list_length):
    if array_length == list_length:
        return array_length
    return 1

def append_N_list_cost(N):
    array_length = 1 # initially the array will have length 1
    list_length = 0 # initially the list has 0 elements
    total_cost = 0 # this variable will keep track of the total cost
    for i in range(N):
        total_cost = append_cost(array_length, list_length)
        total_cost += cost
        # update the array and list lengths
        if array_length == list_length:
            array_length *= 2
        list_length += 1
    return total_cost

# add you code below
costs = []
for i in range(5000):
    cost = append_N_list_cost(i)
    costs.append(cost)

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
ax.plot(costs,label="Real execution time")
ax.set_xlabel("Array Size")
ax.set_ylabel("Cost")

size = len(costs)

z = np.polyfit(range(0, size),costs, 1)
p = np.poly1d(z)

ax.plot(range(0, size),p(range(0, size)),label="Time complexity model")
ax.legend()
plt.show()

# %%
def add_with_append(N):
    values = []
    for i in range(N):
        values.append(i)
    return values

def add_with_insert(N):
    values = []
    for i in range(N):
        values.insert(0, i)
    return values

start = time.time()
add_with_append(50000)
end = time.time()
time_append = end - start

start = time.time()
add_with_insert(50000)
end = time.time()
time_insert = end - start
    
print(time_append)
print(time_insert)
# Out:
# 0.012230873107910156
# 0.7769486904144287

# %%
def random_n_digits(n):
    range_start = 10**(n-1)
    range_end = (10**n)-1
    return randint(range_start, range_end)

# %%
pairs = [(random_n_digits(i),random_n_digits(i)) for i in range (1,20000)]

# %%
pairs[0:15]
# Out:
# [(1, 4),
#  (34, 64),
#  (324, 747),
#  (2400, 9607),
#  (77723, 44305),
#  (528265, 383903),
#  (4382871, 3795031),
#  (53826948, 57325671),
#  (444678713, 820138183),
#  (4244130977, 9988833273),
#  (25064865624, 75070188612),
#  (701340852393, 387663056971),
#  (5002206279284, 6906291015774),
#  (73391620830281, 52223993475578),
#  (761138213843611, 475799687650575)]

# %%
times = []
for x, y in pairs:
    start = time.time()
    z = x * y
    end = time.time()
    times.append(end - start)

# %%
fig, ax = plt.subplots(1,1,figsize=(10,6))
ax.plot(times,label="Real execution time")
ax.set_xlabel("Number of Digits")
ax.set_ylabel("Multiplication runtime (seconds)")

size = len(times)

z = np.polyfit(range(0, size),times, 1)
p = np.poly1d(z)

ax.plot(range(0, size),p(range(0, size)),label="Time complexity model")
ax.legend()
plt.show()
